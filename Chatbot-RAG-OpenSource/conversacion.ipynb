# %%
import chatbot_hemograma
# Out:
# c:\Users\nicol\venv\chatbot_RAG\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
chatbot_hemograma.chat()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 chatbot_hemograma.chat()
#
# File c:\Users\nicol\Documents\Proyectos\Chatbot\Chatbot_Langchain\Chatbot-RAG-OpenSource\chatbot_hemograma.py:47, in chat()
#      44 if pregunta.lower() == "adios":
#      45     break
# ---> 47 response = chain.invoke({"input": pregunta})
#      48 print('-'*120)
#      49 print('AI: ' + response)
#
# File c:\Users\nicol\venv\chatbot_RAG\Lib\site-packages\langchain_core\runnables\base.py:4427, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    4421 def invoke(
#    4422     self,
#    4423     input: Input,
#    4424     config: Optional[RunnableConfig] = None,
#    4425     **kwargs: Optional[Any],
#    4426 ) -> Output:
# -> 4427     return self.bound.invoke(
#    4428         input,
#    4429         self._merge_configs(config),
# ...
